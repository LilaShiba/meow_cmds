# %%
from utils.dataParser import Parser
import seaborn as sns

# %%
db = Parser('/Users/kjams/Desktop/meow_cmds/data')
# Out:
# Error reading /Users/kjams/Desktop/meow_cmds/data/sensor_data_2025-03-22T21:55.csv: No columns to parse from file
# Loaded 27 files with 1529 rows.
# /Users/kjams/Desktop/meow_cmds/utils/parser.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_combined = pd.concat(data_frames, ignore_index=True)

# %%
len(db.df)
# Out:
# 1529

# %%
linear_r_ph = db.linear_regression(target_column="Pressure", feature_columns=["Humidity"])
# Out:
# Mean Squared Error: 20.2728
# Root Mean Squared Error: 4.5025
# Regression Coefficients: [-1.00259341]
# Intercept: 1041.046262003671

# %%
linear_r_ph.predict([[24]])
# Out:
# /Users/kjams/Desktop/meow_cmds/dev/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1016.98402009])

# %%
knn = db.knn_regression(feature_columns=['Pressure'], target_column='Humidity')
# Out:
# Mean Squared Error: 1.7166
# Root Mean Squared Error: 1.3102

# %%
db.plot_heatmap()

# %%
market = Parser('/Users/kjams/Desktop/meow_cmds/historical_data')
# Out:
# Loaded 21 files with 46110 rows.

# %%
market.df.head()
# Out:
#         Price               Close                High                 Low  \
# 0      Ticker                   T                   T                   T
# 1        Date                 NaN                 NaN                 NaN
# 2  2015-01-02  12.027410507202148  12.062921205605607  11.927980731023958
# 3  2015-01-05  11.913775444030762  12.045164751939703  11.903122862820174
# 4  2015-01-06  11.931536674499512  12.006109260722459  11.842760341274651
#
#                  Open    Volume      Sign Symbol   Timestamp
# 0                   T         T       NaN    NaN         NaN
# 1                 NaN       NaN       NaN    NaN         NaN
# 2  11.927980731023958  27226736  Dividend      T  2015-01-02
# 3  12.027409852083789  40288128  Dividend      T  2015-01-05
# 4  11.991904616962731  39184839  Dividend      T  2015-01-06

# %%
market.df.columns
# Out:
# Index(['Price', 'Close', 'High', 'Low', 'Open', 'Volume', 'Sign', 'Symbol',
#        'Timestamp'],
#       dtype='object')
